# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as img
df = pd.read_csv("Downloads/labels_my-project-name_2023-08-03-12-01-47.csv")
df.head()
# Out:
#    label_name  bbox_x  bbox_y  bbox_width  bbox_height     image_name  \
# 0    tigerone      50     212         159          286  ai4 image.jpg
# 1    tigertwo     261     227         209          292  ai4 image.jpg
# 2  tigerthree     533     183         432          606  ai4 image.jpg
# 3   tigerfour    1032     212         380          528  ai4 image.jpg
#
#    image_width  image_height
# 0         1416           800
# 1         1416           800
# 2         1416           800
# 3         1416           800

# %%
df.describe()
# Out:
#             bbox_x      bbox_y  bbox_width  bbox_height  image_width  \
# count     4.000000    4.000000    4.000000     4.000000          4.0
# mean    469.000000  208.500000  295.000000   428.000000       1416.0
# std     424.220854   18.411953  131.511723   163.650033          0.0
# min      50.000000  183.000000  159.000000   286.000000       1416.0
# 25%     208.250000  204.750000  196.500000   290.500000       1416.0
# 50%     397.000000  212.000000  294.500000   410.000000       1416.0
# 75%     657.750000  215.750000  393.000000   547.500000       1416.0
# max    1032.000000  227.000000  432.000000   606.000000       1416.0
#
#        image_height
# count           4.0
# mean          800.0
# std             0.0
# min           800.0
# 25%           800.0
# 50%           800.0
# 75%           800.0
# max           800.0

# %%
df.dropna()
# Out:
#    label_name  bbox_x  bbox_y  bbox_width  bbox_height     image_name  \
# 0    tigerone      50     212         159          286  ai4 image.jpg
# 1    tigertwo     261     227         209          292  ai4 image.jpg
# 2  tigerthree     533     183         432          606  ai4 image.jpg
# 3   tigerfour    1032     212         380          528  ai4 image.jpg
#
#    image_width  image_height
# 0         1416           800
# 1         1416           800
# 2         1416           800
# 3         1416           800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   label_name    4 non-null      object
#  1   bbox_x        4 non-null      int64
#  2   bbox_y        4 non-null      int64
#  3   bbox_width    4 non-null      int64
#  4   bbox_height   4 non-null      int64
#  5   image_name    4 non-null      object
#  6   image_width   4 non-null      int64
#  7   image_height  4 non-null      int64
# dtypes: int64(6), object(2)
# memory usage: 384.0+ bytes

# %%
testimg=img.imread("Downloads/desktop-wallpaper-jungle-animals-real-life-safari-animals.jpg")
plt.imshow(testimg)

# %%
import cv2

# %%
start_point=(4,4)
End_point=(700,700)
color=(255,0,0)
thickness=9

# %%
testimg=cv2.rectangle(testimg,start_point,End_point,color,thickness)

# %%
testimg
# Out:
# array([[[ 22,   7,  14],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 11,  28,  12],
#         [ 15,  33,  11],
#         [ 15,  33,  11]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 19,  36,  20],
#         [ 27,  45,  23],
#         [ 27,  45,  23]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 29,  46,  30],
#         [ 31,  49,  27],
#         [ 31,  49,  27]],
#
#        ...,
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 96, 111,  82],
#         [ 28,  29,  24],
#         [  0,   1,   0]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 87, 102,  73],
#         [ 16,  15,  11],
#         [  1,   0,   0]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
# ...

# %%
cv2.imshow("mass",testimg)
cv2.waitKey(0)

# %%
df.dropna()

# %%
start_point=(4,4)
End_point=(1000,500)
color=(255,0,0)
thickness=9

# %%
testimg=cv2.rectangle(testimg,start_point,End_point,color,thickness)

# %%
testimg

# %%
cv2.imshow("mass",testimg)
cv2.waitKey(0)
